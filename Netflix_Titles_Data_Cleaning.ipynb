# %% [markdown]
# <a href="https://colab.research.google.com/github/JoyMuthoniNjeru/AI-Coursework-2025/blob/main/Netflix_Titles_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATA UNDERSTANDING

# %%
import pandas as pd

#Loading the dataset
df = pd.read_csv("netflix_titles.csv")

# %%
#qn1: Rows and columns in the dataset
rows,cols = df.shape
print(f"The dataset contains {rows} rows and {cols} columns. \n")
# Out:
# The dataset contains 8807 rows and 12 columns.

# %%
#qn2: Datatypes contained in the datasets
print("Data types of each column:")
print(df.dtypes, "\n")
# Out:
# Data types of each column:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#qn3: Is the datasets complete?
missing_values = df.isnull().sum()
total_missing = missing_values.sum()
if total_missing == 0:
  print("The dataset is complete, no missing values found.\n")
else:
  print("The dataset is not complete, there are missing values in some columns.\n")
# Out:
# The dataset is not complete, there are missing values in some columns.

# %%
#qn4: The number of moviesand TV shows in the last 20 rows
last_20 = df.tail(20)
movie_count = last_20[last_20['type'] == 'Movie'].shape[0]
tvshow_count = last_20[last_20['type'] == 'TV Show'].shape[0]
print(f"Among the last 20 rows, there are {movie_count} movies and {tvshow_count} TV shows.")
# Out:
# Among the last 20 rows, there are 15 movies and 5 TV shows.

# %% [markdown]
# DATA INDEXING

# %%
#QN1: Movies originating from South Africa
south_africa_movies = df[(df['type'] == 'Movie') & (df['country'] == 'South Africa')]
num_south_africa_movies = south_africa_movies.shape[0]
print(f"Number of movies from South Africa are {num_south_africa_movies}\n")
# Out:
# Number of movies from South Africa are 24

# %%
#QN2: Movie in the 12th row
description_12th = df.iloc[11]['description']
print(f"Description of the 12th movie: \n")
description_12th
# Out:
# Description of the 12th movie:
# 'Struggling to earn a living in Bangkok, a man joins an emergency rescue service and realizes he must unravel a citywide conspiracy.'

# %%
#QN3: South African movies released in 2021
south_africa_2021 = south_africa_movies[south_africa_movies['release_year'] == 2021]
print("South African movies released in 2021:\n")
south_africa_2021[['title', 'release_year']]
# Out:
# South African movies released in 2021:
#                              title  release_year
# 293                           Slay          2021
# 764   Trippin' with the Kandasamys          2021
# 881                 I Am All Girls          2021
# 1172       Loyiso Gola: Unlearning          2021

# %%
#QN4: Entire cast of all movies released in 2021
movies_2021 = df[(df['type'] == 'Movie') & (df['release_year'] == 2021)]
casts_2021 = movies_2021[['title', 'cast']]
print("Cast of all movies released in 2021:")
casts_2021
# Out:
# Cast of all movies released in 2021:
#                                                   title  \
# 6                      My Little Pony: A New Generation
# 9                                          The Starling
# 12                                         Je Suis Karl
# 13                     Confessions of an Invisible Girl
# 18                                            Intrusion
# ...                                                 ...
# 1425                        Creating The Queen's Gambit
# 1431                                        Stuck Apart
# 1436  Ratones Paranoicos: The Band that Rocked Argen...
# 1466                       The Minimalists: Less Is Now
# 1468                          What Happened to Mr. Cha?
#
#                                                    cast
# 6     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# ...

# %% [markdown]
# ![AIteampic.jpg](data:image/jpeg;base64,...)
